# %% [markdown]
# <a href="https://colab.research.google.com/github/JaccoVeldscholten/SmartDispenser/blob/main/BAVA_API_Insights_Prediction_TVOC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div>
# <img src="data:image/png;base64,..." width="200"/>
# </div>

# %% [markdown]
# **API Validation & Prediction** <br>
# This document will be validate the gathered API Data and will is able to being used for predictions and analyses
#
# ***Temperature Prediction*** <br>
# To start off Machine Learning is being used to predict the temperature of the certain amount of days in the toilet. By using basic regression model (linear) its possible to predict the temperature based on the API data thats being generated by the device.

# %% [markdown]
# # Imports <br>
# In the first stage of the notebook all imports should be made for running the code later on in the notebook

# %%
import urllib.request
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist
import datetime

from sklearn.model_selection import train_test_split

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)

# Disable copy warn
pd.options.mode.chained_assignment = None  # default='warn'
# Out:
# 2.7.0

# %% [markdown]
# # Fetching API <br>
# First gather the API Data from the URL. After that print the first elements of the fetched data

# %%
with urllib.request.urlopen("https://us-central1-bava-solutions.cloudfunctions.net/GetLogsOfADevice/.F0:08:D1:D8:07:D4") as url:
    data = json.loads(url.read().decode())

# %%
df = pd.DataFrame(data)
df.tail()
# df['timestamp'][0]
# Out:
#                    mac  ...                                          timestamp
# 120  F0:08:D1:D8:07:D4  ...  {'_seconds': 1639594946, '_nanoseconds': 83100...
# 121  F0:08:D1:D8:07:D4  ...  {'_seconds': 1639594947, '_nanoseconds': 39800...
# 122  F0:08:D1:D8:07:D4  ...  {'_seconds': 1639595548, '_nanoseconds': 61700...
# 123        gshshshshsh  ...  {'_seconds': 1639603953, '_nanoseconds': 10700...
# 124             svgssg  ...  {'_seconds': 1639603964, '_nanoseconds': 35600...
#
# [5 rows x 11 columns]

# %% [markdown]
# # Plotting the data

# %%
df.plot(x='timestamp', y='tvoc_co2')

# %%
# Reading TVOC
df = pd.DataFrame(data)
df.plot(x='timestamp', y='tvoc_ppm')

# %%
# Reading humidty
df.plot(x='timestamp', y='hum')

# %%
# Reading tvoc_ppmerature
df.plot(x='timestamp', y='tvoc_ppm')

# %% [markdown]
# # The numbers mason <br>
# The numbers mason what do they mean?

# %%
# Getting all triggers by occupation
triggerd_by_occupation = df[df['occupied']==1]
triggerd_by_occupation.count()['occupied']
# Out:
# 34

# %%
# Getting all triggers by timer
triggerd_by_timer = df[df['occupied']==0]
triggerd_by_timer.count()['occupied']
# Out:
# 91

# %% [markdown]
# # Predictions <br>
# **Predictions based on Machine learning data**<br>
# First prediction is determining what the temperature might be in a few days.

# %%
# Tensorflow
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# #Clean the data. Drop any columns with missing values or null values.
#
# dropping timestamp and mac because they are categorical and irrelevant.
#
# dropping batterylevel and waterlevel because they all have same data.

# %%
dataset = df.copy()
dataset.isna().sum()

#dataset.dropna()
cleaned_dataset = dataset.drop(['mac', 'batteryLevel', 'liquidLevel', 'occupied'], axis=1)


tvoc_ppm = cleaned_dataset

for i in range(len(cleaned_dataset['timestamp'])):
  cleaned_dataset['timestamp'][i] = datetime.datetime.utcfromtimestamp((cleaned_dataset['timestamp'][i]['_seconds']) ).strftime('%Y-%m-%d')

cleaned_dataset.index = pd.to_datetime(cleaned_dataset['timestamp'])
cleaned_dataset = cleaned_dataset[cleaned_dataset['temp'] != 0]
cleaned_dataset = cleaned_dataset.drop(['timestamp'], axis=1)
#cleaned_dataset

# %% [markdown]
# #Splitting for regression using Tensorflow

# %%
train_data = cleaned_dataset.sample(frac=0.5, random_state=0)

test_data = cleaned_dataset.sample(frac=0.2, random_state=0)

# test_data

# cleaned_dataset = cleaned_dataset.drop(['timestamp'], axis=1)

# train_data, test_data = np.split(cleaned_dataset, [int(.3 *len(data))])

train_data
print(len(test_data), len(train_data), len(cleaned_dataset))

# Y = cleaned_dataset['tvoc_ppm']
# x = cleaned_dataset.loc[:, cleaned_dataset.columns != 'tvoc_ppm']
# Out:
# 25 62 125

# %% [markdown]
# #Split attributes and labels apart

# %%
train_features = cleaned_dataset.copy()
test_features = cleaned_dataset.copy()

train_labels = train_features.pop('tvoc_ppm')
test_labels = test_features.pop('tvoc_ppm')



train_labels

train_data = train_data.drop(['tvoc_ppm'], axis=1)
test_data = test_data.drop(['tvoc_ppm'], axis=1)

print(test_data)

# train_dataset_timeseries = keras.preprocessing.timeseries_dataset_from_array(train_data, train_labels, sequence_length=len(train_data))
# TimeSeries
# Out:
#             altitude  pressure  temp  tvoc_co2  hum
# timestamp
# 2021-12-15      -138    102935    23       420   52
# 2021-12-15      -136    102910    23       400   50
# 2021-12-15      -135    102907    23       400   51
# 2021-12-15      -136    102912    23       400   50
# 2021-12-15      -136    102919    23       407   49
# 2021-12-15      -144    103014    23       405   46
# 2021-12-15      -135    102904    23       405   50
# 2021-12-15      -141    102972    23       402   47
# 2021-12-15      -137    102931    22       413   50
# 2021-12-15      -151    103090    23       400   44
# 2021-12-15      -136    102925    23       400   51
# 2021-12-15      -138    102939    23       403   49
# 2021-12-15      -144    103014    23       400   46
# 2021-12-15      -135    102899    23       405   50
# 2021-12-15      -140    102967    23       402   47
# 2021-12-15      -137    102930    22       400   52
# 2021-12-15      -143    103003    23       400   46
# 2021-12-15      -139    102945    23       408   48
# 2021-12-15      -135    102903    23       402   50
# 2021-12-15      -135    102907    23       417   51
# 2021-12-15      -135    102901    23       400   49
# 2021-12-15      -142    102984    23       402   47
# 2021-12-15      -142    102981    23       414   46
# 2021-12-15      -136    102912    23       407   50
# 2021-12-15      -136    102909    23       407   50

# %%
train_stat = train_data.describe().transpose()[['mean', 'std']]
train_stat
# Out:
#                    mean           std
# altitude    -136.951613     18.221252
# pressure  101292.032258  13075.249943
# temp          23.000000      0.829774
# tvoc_co2     397.274194     50.835050
# hum           47.887097      5.486511

# %% [markdown]
# #Normalization
# ***Normalizing is helpful to bound data between the range from 0 to 1***

# %%
def normalize(row):
  # t = row['timestamp']
  

  answer = (row - train_stat['mean']) / train_stat['std']
  print(row, answer)
  # answer['timestamp'] = t
  
  return answer

normed_train = normalize(train_data)
normed_test = normalize(test_data)

print(normed_test)



normed_train = np.asarray(normed_train).astype(np.float32)
normed_test = np.asarray(normed_test).astype(np.float32)

# normed_train
# normed_test
train_labels
# Out:
#             altitude  pressure  temp  tvoc_co2  hum
# timestamp
# 2021-12-15      -138    102935    23       420   52
# 2021-12-15      -136    102910    23       400   50
# 2021-12-15      -135    102907    23       400   51
# 2021-12-15      -136    102912    23       400   50
# 2021-12-15      -136    102919    23       407   49
# ...              ...       ...   ...       ...  ...
# 2021-12-15      -135    102906    23       400   49
# 2021-12-15      -135    102905    23       400   50
# 2021-12-15      -137    102931    22       400   52
# 2021-12-15      -136    102920    23       400   51
# 2021-12-15      -135    102905    23       409   50
#
# [62 rows x 5 columns]             altitude  pressure      temp  tvoc_co2       hum
# timestamp
# 2021-12-15 -0.057537  0.125655  0.000000  0.447050  0.749639
# 2021-12-15  0.052225  0.123743  0.000000  0.053621  0.385109
# 2021-12-15  0.107106  0.123513  0.000000  0.053621  0.567374
# 2021-12-15  0.052225  0.123896  0.000000  0.053621  0.385109
# 2021-12-15  0.052225  0.124431  0.000000  0.191321  0.202844
# ...              ...       ...       ...       ...       ...
# 2021-12-15  0.107106  0.123437  0.000000  0.053621  0.202844
# 2021-12-15  0.107106  0.123360  0.000000  0.053621  0.385109
# 2021-12-15 -0.002656  0.125349 -1.205148  0.053621  0.749639
# 2021-12-15  0.052225  0.124508  0.000000  0.053621  0.567374
# 2021-12-15  0.107106  0.123360  0.000000  0.230664  0.385109
#
# [62 rows x 5 columns]
#             altitude  pressure  temp  tvoc_co2  hum
# timestamp
# 2021-12-15      -138    102935    23       420   52
# 2021-12-15      -136    102910    23       400   50
# 2021-12-15      -135    102907    23       400   51
# 2021-12-15      -136    102912    23       400   50
# 2021-12-15      -136    102919    23       407   49
# 2021-12-15      -144    103014    23       405   46
# 2021-12-15      -135    102904    23       405   50
# 2021-12-15      -141    102972    23       402   47
# 2021-12-15      -137    102931    22       413   50
# 2021-12-15      -151    103090    23       400   44
# 2021-12-15      -136    102925    23       400   51
# 2021-12-15      -138    102939    23       403   49
# 2021-12-15      -144    103014    23       400   46
# 2021-12-15      -135    102899    23       405   50
# 2021-12-15      -140    102967    23       402   47
# 2021-12-15      -137    102930    22       400   52
# 2021-12-15      -143    103003    23       400   46
# 2021-12-15      -139    102945    23       408   48
# 2021-12-15      -135    102903    23       402   50
# 2021-12-15      -135    102907    23       417   51
# 2021-12-15      -135    102901    23       400   49
# 2021-12-15      -142    102984    23       402   47
# 2021-12-15      -142    102981    23       414   46
# 2021-12-15      -136    102912    23       407   50
# 2021-12-15      -136    102909    23       407   50             altitude  pressure      temp  tvoc_co2       hum
# timestamp
# 2021-12-15 -0.057537  0.125655  0.000000  0.447050  0.749639
# 2021-12-15  0.052225  0.123743  0.000000  0.053621  0.385109
# 2021-12-15  0.107106  0.123513  0.000000  0.053621  0.567374
# 2021-12-15  0.052225  0.123896  0.000000  0.053621  0.385109
# 2021-12-15  0.052225  0.124431  0.000000  0.191321  0.202844
# 2021-12-15 -0.386822  0.131697  0.000000  0.151978 -0.343952
# 2021-12-15  0.107106  0.123284  0.000000  0.151978  0.385109
# 2021-12-15 -0.222179  0.128485  0.000000  0.092964 -0.161687
# 2021-12-15 -0.002656  0.125349 -1.205148  0.309350  0.385109
# 2021-12-15 -0.770989  0.137509  0.000000  0.053621 -0.708483
# 2021-12-15  0.052225  0.124890  0.000000  0.053621  0.567374
# 2021-12-15 -0.057537  0.125961  0.000000  0.112635  0.202844
# 2021-12-15 -0.386822  0.131697  0.000000  0.053621 -0.343952
# 2021-12-15  0.107106  0.122901  0.000000  0.151978  0.385109
# 2021-12-15 -0.167298  0.128102  0.000000  0.092964 -0.161687
# 2021-12-15 -0.002656  0.125272 -1.205148  0.053621  0.749639
# 2021-12-15 -0.331941  0.130855  0.000000  0.053621 -0.343952
# 2021-12-15 -0.112417  0.126420  0.000000  0.210992  0.020578
# 2021-12-15  0.107106  0.123207  0.000000  0.092964  0.385109
# 2021-12-15  0.107106  0.123513  0.000000  0.388036  0.567374
# 2021-12-15  0.107106  0.123054  0.000000  0.053621  0.202844
# 2021-12-15 -0.277060  0.129402  0.000000  0.092964 -0.161687
# 2021-12-15 -0.277060  0.129173  0.000000  0.329021 -0.343952
# 2021-12-15  0.052225  0.123896  0.000000  0.191321  0.385109
# 2021-12-15  0.052225  0.123666  0.000000  0.191321  0.385109
#             altitude  pressure      temp  tvoc_co2       hum
# timestamp
# 2021-12-15 -0.057537  0.125655  0.000000  0.447050  0.749639
# 2021-12-15  0.052225  0.123743  0.000000  0.053621  0.385109
# 2021-12-15  0.107106  0.123513  0.000000  0.053621  0.567374
# 2021-12-15  0.052225  0.123896  0.000000  0.053621  0.385109
# 2021-12-15  0.052225  0.124431  0.000000  0.191321  0.202844
# 2021-12-15 -0.386822  0.131697  0.000000  0.151978 -0.343952
# 2021-12-15  0.107106  0.123284  0.000000  0.151978  0.385109
# 2021-12-15 -0.222179  0.128485  0.000000  0.092964 -0.161687
# 2021-12-15 -0.002656  0.125349 -1.205148  0.309350  0.385109
# 2021-12-15 -0.770989  0.137509  0.000000  0.053621 -0.708483
# 2021-12-15  0.052225  0.124890  0.000000  0.053621  0.567374
# 2021-12-15 -0.057537  0.125961  0.000000  0.112635  0.202844
# 2021-12-15 -0.386822  0.131697  0.000000  0.053621 -0.343952
# 2021-12-15  0.107106  0.122901  0.000000  0.151978  0.385109
# 2021-12-15 -0.167298  0.128102  0.000000  0.092964 -0.161687
# 2021-12-15 -0.002656  0.125272 -1.205148  0.053621  0.749639
# 2021-12-15 -0.331941  0.130855  0.000000  0.053621 -0.343952
# 2021-12-15 -0.112417  0.126420  0.000000  0.210992  0.020578
# 2021-12-15  0.107106  0.123207  0.000000  0.092964  0.385109
# 2021-12-15  0.107106  0.123513  0.000000  0.388036  0.567374
# 2021-12-15  0.107106  0.123054  0.000000  0.053621  0.202844
# 2021-12-15 -0.277060  0.129402  0.000000  0.092964 -0.161687
# 2021-12-15 -0.277060  0.129173  0.000000  0.329021 -0.343952
# 2021-12-15  0.052225  0.123896  0.000000  0.191321  0.385109
# 2021-12-15  0.052225  0.123666  0.000000  0.191321  0.385109
# timestamp
# 2021-12-15     0
# 2021-12-15     0
# 2021-12-15     0
# 2021-12-15     0
# 2021-12-15     0
#               ..
# 2021-12-15     0
# 2021-12-15     0
# 2021-12-15     0
# 2021-12-15    29
# 2021-12-15     5
# Name: tvoc_ppm, Length: 125, dtype: int64

# %% [markdown]
# #Building the model using Tensorflow Keras

# %%
# For building the model using function for in the future its better to create multiple models
def create_model():
  model = keras.Sequential([
      layers.Dense(64, activation=tf.nn.relu, input_shape=[len(train_data.keys())]),
      layers.Dense(1)
  ])

  optimiser = tf.keras.optimizers.RMSprop(0.001)
  model.compile(loss='mse', optimizer=optimiser, metrics=['mae', 'mse'])

  return model

# %%
model = create_model()

# %% [markdown]
# #Insights of the model

# %%
model.summary() # Overview of the created model
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                384
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 449
# Trainable params: 449
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_block = keras.callbacks.EarlyStopping(monitor='val_loss', patience=100)                                     # Add auto stop incase the loss is less enough.
full_model = model.fit(normed_train, train_labels, epochs=10000, validation_split=0.2, callbacks=[early_block])   # Actual model training
# Out:
# Epoch 1/10000
# 2/2 [==============================] - 1s 177ms/step - loss: 5.2676 - mae: 0.7720 - mse: 5.2676 - val_loss: 0.1563 - val_mae: 0.2820 - val_mse: 0.1563
# Epoch 2/10000
# 2/2 [==============================] - 0s 34ms/step - loss: 5.1803 - mae: 0.7759 - mse: 5.1803 - val_loss: 0.1565 - val_mae: 0.3045 - val_mse: 0.1565
# Epoch 3/10000
# 2/2 [==============================] - 0s 34ms/step - loss: 5.1251 - mae: 0.7863 - mse: 5.1251 - val_loss: 0.1585 - val_mae: 0.3244 - val_mse: 0.1585
# Epoch 4/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 5.0819 - mae: 0.8024 - mse: 5.0819 - val_loss: 0.1619 - val_mae: 0.3387 - val_mse: 0.1619
# Epoch 5/10000
# 2/2 [==============================] - 0s 30ms/step - loss: 5.0495 - mae: 0.8068 - mse: 5.0495 - val_loss: 0.1674 - val_mae: 0.3561 - val_mse: 0.1674
# Epoch 6/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 5.0058 - mae: 0.8203 - mse: 5.0058 - val_loss: 0.1708 - val_mae: 0.3647 - val_mse: 0.1708
# Epoch 7/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 4.9828 - mae: 0.8244 - mse: 4.9828 - val_loss: 0.1777 - val_mae: 0.3792 - val_mse: 0.1777
# Epoch 8/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 4.9530 - mae: 0.8361 - mse: 4.9530 - val_loss: 0.1832 - val_mae: 0.3881 - val_mse: 0.1832
# Epoch 9/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.9334 - mae: 0.8361 - mse: 4.9334 - val_loss: 0.1906 - val_mae: 0.3998 - val_mse: 0.1906
# Epoch 10/10000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.9052 - mae: 0.8445 - mse: 4.9052 - val_loss: 0.1967 - val_mae: 0.4082 - val_mse: 0.1967
# Epoch 11/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 4.8885 - mae: 0.8469 - mse: 4.8885 - val_loss: 0.2016 - val_mae: 0.4152 - val_mse: 0.2016
# Epoch 12/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 4.8722 - mae: 0.8482 - mse: 4.8722 - val_loss: 0.2112 - val_mae: 0.4276 - val_mse: 0.2112
# Epoch 13/10000
# 2/2 [==============================] - 0s 22ms/step - loss: 4.8449 - mae: 0.8556 - mse: 4.8449 - val_loss: 0.2167 - val_mae: 0.4337 - val_mse: 0.2167
# Epoch 14/10000
# 2/2 [==============================] - 0s 29ms/step - loss: 4.8304 - mae: 0.8588 - mse: 4.8304 - val_loss: 0.2215 - val_mae: 0.4384 - val_mse: 0.2215
# Epoch 15/10000
# 2/2 [==============================] - 0s 28ms/step - loss: 4.8150 - mae: 0.8616 - mse: 4.8150 - val_loss: 0.2305 - val_mae: 0.4477 - val_mse: 0.2305
# Epoch 16/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 4.7937 - mae: 0.8734 - mse: 4.7937 - val_loss: 0.2354 - val_mae: 0.4514 - val_mse: 0.2354
# Epoch 17/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 4.7760 - mae: 0.8671 - mse: 4.7760 - val_loss: 0.2467 - val_mae: 0.4620 - val_mse: 0.2467
# Epoch 18/10000
# 2/2 [==============================] - 0s 34ms/step - loss: 4.7549 - mae: 0.8747 - mse: 4.7549 - val_loss: 0.2513 - val_mae: 0.4650 - val_mse: 0.2513
# Epoch 19/10000
# 2/2 [==============================] - 0s 22ms/step - loss: 4.7387 - mae: 0.8705 - mse: 4.7387 - val_loss: 0.2599 - val_mae: 0.4729 - val_mse: 0.2599
# Epoch 20/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.7278 - mae: 0.8772 - mse: 4.7278 - val_loss: 0.2683 - val_mae: 0.4804 - val_mse: 0.2683
# Epoch 21/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 4.7111 - mae: 0.8774 - mse: 4.7111 - val_loss: 0.2772 - val_mae: 0.4880 - val_mse: 0.2772
# Epoch 22/10000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.6968 - mae: 0.8815 - mse: 4.6968 - val_loss: 0.2851 - val_mae: 0.4936 - val_mse: 0.2851
# Epoch 23/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.6830 - mae: 0.8862 - mse: 4.6830 - val_loss: 0.2926 - val_mae: 0.4985 - val_mse: 0.2926
# Epoch 24/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 4.6677 - mae: 0.8851 - mse: 4.6677 - val_loss: 0.3026 - val_mae: 0.5060 - val_mse: 0.3026
# Epoch 25/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.6544 - mae: 0.8935 - mse: 4.6544 - val_loss: 0.3107 - val_mae: 0.5108 - val_mse: 0.3107
# Epoch 26/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 4.6383 - mae: 0.8905 - mse: 4.6383 - val_loss: 0.3212 - val_mae: 0.5183 - val_mse: 0.3212
# Epoch 27/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 4.6249 - mae: 0.8924 - mse: 4.6249 - val_loss: 0.3313 - val_mae: 0.5253 - val_mse: 0.3313
# Epoch 28/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 4.6115 - mae: 0.8960 - mse: 4.6115 - val_loss: 0.3374 - val_mae: 0.5278 - val_mse: 0.3374
# Epoch 29/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.5977 - mae: 0.8934 - mse: 4.5977 - val_loss: 0.3542 - val_mae: 0.5373 - val_mse: 0.3542
# Epoch 30/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 4.5717 - mae: 0.8984 - mse: 4.5717 - val_loss: 0.3678 - val_mae: 0.5445 - val_mse: 0.3678
# Epoch 31/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 4.5523 - mae: 0.9020 - mse: 4.5523 - val_loss: 0.3745 - val_mae: 0.5481 - val_mse: 0.3745
# Epoch 32/10000
# 2/2 [==============================] - 0s 32ms/step - loss: 4.5415 - mae: 0.9044 - mse: 4.5415 - val_loss: 0.3824 - val_mae: 0.5524 - val_mse: 0.3824
# Epoch 33/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 4.5363 - mae: 0.9043 - mse: 4.5363 - val_loss: 0.4002 - val_mae: 0.5628 - val_mse: 0.4002
# Epoch 34/10000
# 2/2 [==============================] - 0s 32ms/step - loss: 4.5126 - mae: 0.9136 - mse: 4.5126 - val_loss: 0.4139 - val_mae: 0.5695 - val_mse: 0.4139
# Epoch 35/10000
# 2/2 [==============================] - 0s 34ms/step - loss: 4.4957 - mae: 0.9131 - mse: 4.4957 - val_loss: 0.4171 - val_mae: 0.5691 - val_mse: 0.4171
# Epoch 36/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.4890 - mae: 0.9113 - mse: 4.4890 - val_loss: 0.4304 - val_mae: 0.5744 - val_mse: 0.4304
# Epoch 37/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 4.4695 - mae: 0.9131 - mse: 4.4695 - val_loss: 0.4376 - val_mae: 0.5771 - val_mse: 0.4376
# Epoch 38/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.4613 - mae: 0.9144 - mse: 4.4613 - val_loss: 0.4446 - val_mae: 0.5796 - val_mse: 0.4446
# Epoch 39/10000
# 2/2 [==============================] - 0s 29ms/step - loss: 4.4523 - mae: 0.9146 - mse: 4.4523 - val_loss: 0.4520 - val_mae: 0.5824 - val_mse: 0.4520
# Epoch 40/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 4.4428 - mae: 0.9119 - mse: 4.4428 - val_loss: 0.4590 - val_mae: 0.5847 - val_mse: 0.4590
# Epoch 41/10000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.4335 - mae: 0.9121 - mse: 4.4335 - val_loss: 0.4675 - val_mae: 0.5868 - val_mse: 0.4675
# Epoch 42/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.4230 - mae: 0.9121 - mse: 4.4230 - val_loss: 0.4756 - val_mae: 0.5900 - val_mse: 0.4756
# Epoch 43/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 4.4159 - mae: 0.9096 - mse: 4.4159 - val_loss: 0.4967 - val_mae: 0.5998 - val_mse: 0.4967
# Epoch 44/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.3974 - mae: 0.9191 - mse: 4.3974 - val_loss: 0.5021 - val_mae: 0.6005 - val_mse: 0.5021
# Epoch 45/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.3851 - mae: 0.9124 - mse: 4.3851 - val_loss: 0.5153 - val_mae: 0.6070 - val_mse: 0.5153
# Epoch 46/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 4.3776 - mae: 0.9174 - mse: 4.3776 - val_loss: 0.5216 - val_mae: 0.6083 - val_mse: 0.5216
# Epoch 47/10000
# 2/2 [==============================] - 0s 27ms/step - loss: 4.3719 - mae: 0.9170 - mse: 4.3719 - val_loss: 0.5259 - val_mae: 0.6088 - val_mse: 0.5259
# Epoch 48/10000
# 2/2 [==============================] - 0s 29ms/step - loss: 4.3637 - mae: 0.9136 - mse: 4.3637 - val_loss: 0.5464 - val_mae: 0.6161 - val_mse: 0.5464
# Epoch 49/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 4.3532 - mae: 0.9157 - mse: 4.3532 - val_loss: 0.5672 - val_mae: 0.6260 - val_mse: 0.5672
# Epoch 50/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 4.3301 - mae: 0.9206 - mse: 4.3301 - val_loss: 0.5747 - val_mae: 0.6291 - val_mse: 0.5747
# Epoch 51/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 4.3276 - mae: 0.9236 - mse: 4.3276 - val_loss: 0.5756 - val_mae: 0.6281 - val_mse: 0.5756
# Epoch 52/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.3245 - mae: 0.9171 - mse: 4.3245 - val_loss: 0.5977 - val_mae: 0.6377 - val_mse: 0.5977
# Epoch 53/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 4.3049 - mae: 0.9217 - mse: 4.3049 - val_loss: 0.6086 - val_mae: 0.6426 - val_mse: 0.6086
# Epoch 54/10000
# 2/2 [==============================] - 0s 34ms/step - loss: 4.2979 - mae: 0.9245 - mse: 4.2979 - val_loss: 0.6151 - val_mae: 0.6438 - val_mse: 0.6151
# Epoch 55/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 4.2929 - mae: 0.9246 - mse: 4.2929 - val_loss: 0.6209 - val_mae: 0.6460 - val_mse: 0.6209
# Epoch 56/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.2887 - mae: 0.9260 - mse: 4.2887 - val_loss: 0.6237 - val_mae: 0.6449 - val_mse: 0.6237
# Epoch 57/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.2808 - mae: 0.9235 - mse: 4.2808 - val_loss: 0.6337 - val_mae: 0.6503 - val_mse: 0.6337
# Epoch 58/10000
# 2/2 [==============================] - 0s 29ms/step - loss: 4.2782 - mae: 0.9256 - mse: 4.2782 - val_loss: 0.6597 - val_mae: 0.6613 - val_mse: 0.6597
# Epoch 59/10000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.2598 - mae: 0.9314 - mse: 4.2598 - val_loss: 0.6682 - val_mae: 0.6638 - val_mse: 0.6682
# Epoch 60/10000
# 2/2 [==============================] - 0s 37ms/step - loss: 4.2624 - mae: 0.9333 - mse: 4.2624 - val_loss: 0.6897 - val_mae: 0.6709 - val_mse: 0.6897
# Epoch 61/10000
# 2/2 [==============================] - 0s 28ms/step - loss: 4.2453 - mae: 0.9373 - mse: 4.2453 - val_loss: 0.6877 - val_mae: 0.6682 - val_mse: 0.6877
# Epoch 62/10000
# 2/2 [==============================] - 0s 50ms/step - loss: 4.2369 - mae: 0.9278 - mse: 4.2369 - val_loss: 0.6924 - val_mae: 0.6697 - val_mse: 0.6924
# Epoch 63/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 4.2310 - mae: 0.9265 - mse: 4.2310 - val_loss: 0.6980 - val_mae: 0.6712 - val_mse: 0.6980
# Epoch 64/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.2255 - mae: 0.9246 - mse: 4.2255 - val_loss: 0.7042 - val_mae: 0.6726 - val_mse: 0.7042
# Epoch 65/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.2279 - mae: 0.9233 - mse: 4.2279 - val_loss: 0.7276 - val_mae: 0.6806 - val_mse: 0.7276
# Epoch 66/10000
# 2/2 [==============================] - 0s 28ms/step - loss: 4.2059 - mae: 0.9276 - mse: 4.2059 - val_loss: 0.7350 - val_mae: 0.6819 - val_mse: 0.7350
# Epoch 67/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.2023 - mae: 0.9292 - mse: 4.2023 - val_loss: 0.7377 - val_mae: 0.6814 - val_mse: 0.7377
# Epoch 68/10000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.1971 - mae: 0.9278 - mse: 4.1971 - val_loss: 0.7420 - val_mae: 0.6823 - val_mse: 0.7420
# Epoch 69/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 4.1956 - mae: 0.9225 - mse: 4.1956 - val_loss: 0.7686 - val_mae: 0.6923 - val_mse: 0.7686
# Epoch 70/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 4.1786 - mae: 0.9310 - mse: 4.1786 - val_loss: 0.7770 - val_mae: 0.6934 - val_mse: 0.7770
# Epoch 71/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 4.1733 - mae: 0.9289 - mse: 4.1733 - val_loss: 0.7816 - val_mae: 0.6952 - val_mse: 0.7816
# Epoch 72/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 4.1714 - mae: 0.9320 - mse: 4.1714 - val_loss: 0.7820 - val_mae: 0.6931 - val_mse: 0.7820
# Epoch 73/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 4.1679 - mae: 0.9230 - mse: 4.1679 - val_loss: 0.8082 - val_mae: 0.7017 - val_mse: 0.8082
# Epoch 74/10000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.1528 - mae: 0.9301 - mse: 4.1528 - val_loss: 0.8180 - val_mae: 0.7066 - val_mse: 0.8180
# Epoch 75/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 4.1463 - mae: 0.9272 - mse: 4.1463 - val_loss: 0.8277 - val_mae: 0.7113 - val_mse: 0.8277
# Epoch 76/10000
# 2/2 [==============================] - 0s 32ms/step - loss: 4.1425 - mae: 0.9321 - mse: 4.1425 - val_loss: 0.8305 - val_mae: 0.7093 - val_mse: 0.8305
# Epoch 77/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 4.1399 - mae: 0.9293 - mse: 4.1399 - val_loss: 0.8318 - val_mae: 0.7074 - val_mse: 0.8318
# Epoch 78/10000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.1319 - mae: 0.9206 - mse: 4.1319 - val_loss: 0.8568 - val_mae: 0.7138 - val_mse: 0.8568
# Epoch 79/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 4.1227 - mae: 0.9228 - mse: 4.1227 - val_loss: 0.8786 - val_mae: 0.7198 - val_mse: 0.8786
# Epoch 80/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 4.1122 - mae: 0.9243 - mse: 4.1122 - val_loss: 0.9015 - val_mae: 0.7264 - val_mse: 0.9015
# Epoch 81/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.0995 - mae: 0.9293 - mse: 4.0995 - val_loss: 0.9030 - val_mae: 0.7248 - val_mse: 0.9030
# Epoch 82/10000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.1035 - mae: 0.9247 - mse: 4.1035 - val_loss: 0.9302 - val_mae: 0.7350 - val_mse: 0.9302
# Epoch 83/10000
# 2/2 [==============================] - 0s 22ms/step - loss: 4.0862 - mae: 0.9310 - mse: 4.0862 - val_loss: 0.9289 - val_mae: 0.7337 - val_mse: 0.9289
# Epoch 84/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.0859 - mae: 0.9265 - mse: 4.0859 - val_loss: 0.9506 - val_mae: 0.7389 - val_mse: 0.9506
# Epoch 85/10000
# 2/2 [==============================] - 0s 27ms/step - loss: 4.0756 - mae: 0.9308 - mse: 4.0756 - val_loss: 0.9719 - val_mae: 0.7473 - val_mse: 0.9719
# Epoch 86/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 4.0655 - mae: 0.9349 - mse: 4.0655 - val_loss: 0.9915 - val_mae: 0.7524 - val_mse: 0.9915
# Epoch 87/10000
# 2/2 [==============================] - 0s 33ms/step - loss: 4.0556 - mae: 0.9403 - mse: 4.0556 - val_loss: 0.9920 - val_mae: 0.7513 - val_mse: 0.9920
# Epoch 88/10000
# 2/2 [==============================] - 0s 28ms/step - loss: 4.0481 - mae: 0.9316 - mse: 4.0481 - val_loss: 0.9960 - val_mae: 0.7523 - val_mse: 0.9960
# Epoch 89/10000
# 2/2 [==============================] - 0s 29ms/step - loss: 4.0451 - mae: 0.9276 - mse: 4.0451 - val_loss: 1.0166 - val_mae: 0.7569 - val_mse: 1.0166
# Epoch 90/10000
# 2/2 [==============================] - 0s 28ms/step - loss: 4.0329 - mae: 0.9284 - mse: 4.0329 - val_loss: 1.0253 - val_mae: 0.7607 - val_mse: 1.0253
# Epoch 91/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 4.0288 - mae: 0.9301 - mse: 4.0288 - val_loss: 1.0294 - val_mae: 0.7627 - val_mse: 1.0294
# Epoch 92/10000
# 2/2 [==============================] - 0s 27ms/step - loss: 4.0243 - mae: 0.9299 - mse: 4.0243 - val_loss: 1.0298 - val_mae: 0.7597 - val_mse: 1.0298
# Epoch 93/10000
# 2/2 [==============================] - 0s 29ms/step - loss: 4.0194 - mae: 0.9255 - mse: 4.0194 - val_loss: 1.0316 - val_mae: 0.7604 - val_mse: 1.0316
# Epoch 94/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.0143 - mae: 0.9234 - mse: 4.0143 - val_loss: 1.0310 - val_mae: 0.7588 - val_mse: 1.0310
# Epoch 95/10000
# 2/2 [==============================] - 0s 32ms/step - loss: 4.0124 - mae: 0.9220 - mse: 4.0124 - val_loss: 1.0304 - val_mae: 0.7569 - val_mse: 1.0304
# Epoch 96/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 4.0040 - mae: 0.9172 - mse: 4.0040 - val_loss: 1.0425 - val_mae: 0.7577 - val_mse: 1.0425
# Epoch 97/10000
# 2/2 [==============================] - 0s 27ms/step - loss: 4.0037 - mae: 0.9176 - mse: 4.0037 - val_loss: 1.0405 - val_mae: 0.7569 - val_mse: 1.0405
# Epoch 98/10000
# 2/2 [==============================] - 0s 28ms/step - loss: 4.0084 - mae: 0.9170 - mse: 4.0084 - val_loss: 1.0732 - val_mae: 0.7655 - val_mse: 1.0732
# Epoch 99/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 3.9892 - mae: 0.9231 - mse: 3.9892 - val_loss: 1.0715 - val_mae: 0.7639 - val_mse: 1.0715
# Epoch 100/10000
# 2/2 [==============================] - 0s 47ms/step - loss: 3.9842 - mae: 0.9205 - mse: 3.9842 - val_loss: 1.0804 - val_mae: 0.7656 - val_mse: 1.0804
# Epoch 101/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.9781 - mae: 0.9174 - mse: 3.9781 - val_loss: 1.0882 - val_mae: 0.7679 - val_mse: 1.0882

# %% [markdown]
# # Model training validation
# How well did the model trained? How is the loss?

# %%
losses = pd.DataFrame(model.history.history)
losses.plot() # Plot the loss

# %% [markdown]
# ## Model Testing

# %%
# Tesing the Model based on values from training X = Time , Y = Predicted temperature
testmodel = pd.DataFrame(model.predict(normed_test))
testmodel.plot()

# %%
# Predict what the TVOC will be after x amount of days
howmany = 1 # 10 days
answer = model.predict([normed_test[0:(howmany % len(normed_test))]])
print(f"The tvoc would be {answer.mean()} ppm after {howmany}")
# Out:
# The tvoc would be 0.7392183542251587 ppm after 1
